# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalinina/Assignment3/blob/master/AI_Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#+++++++++++++EXERCISE-1+++++++++++++++++++++++++++++++++++
import numpy as np
import matplotlib.pyplot as plt

def throw_dice(num_throws):
    dice1 = np.random.randint(1, 7, size=num_throws)
    dice2 = np.random.randint(1, 7, size=num_throws)

    sum_of_dice = dice1 + dice2
    return sum_of_dice

def calculate_probabilities(sum_of_dice):
    unique_sums, counts = np.unique(sum_of_dice, return_counts=True)
    probabilities = counts / sum(counts)
    result = {sum_val: prob for sum_val, prob in zip(unique_sums, probabilities)}
    return result

num_throws = 1000000

sum_of_dice = throw_dice(num_throws)
probabilities = calculate_probabilities(sum_of_dice)

sums = list(probabilities.keys())
probs = list(probabilities.values())

plt.bar(sums, probs)
plt.xticks(range(2, 13))
plt.show()
print('=' * 200)
#++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

import numpy as np
import matplotlib.pyplot as plt


import numpy as np

def throw_dice(num_throws):
    dice1 = np.random.randint(1, 7, size=num_throws)
    dice2 = np.random.randint(1, 7, size=num_throws)
    sum_of_dice = dice1 + dice2
    return sum_of_dice

def calculate_probabilities(sum_of_dice):
    unique_sums, counts = np.unique(sum_of_dice, return_counts=True)
    probabilities = counts / sum(counts)
    result = {sum_val: prob for sum_val, prob in zip(unique_sums, probabilities)}
    return result

n_values = [500, 1000, 2000, 5000, 10000, 15000, 20000, 50000, 100000]

for n in n_values:
    print(f"Number of throws: {n}")

    sum_of_dice = throw_dice(n)

    probabilities = calculate_probabilities(sum_of_dice)


    sums = list(probabilities.keys())
    probs = list(probabilities.values())

    plt.bar(sums, probs)
    plt.xticks(range(2, 13))

    plt.show()

    print('=' * 200)
#++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
import numpy as np
import matplotlib.pyplot as plt

def calculate_probabilities(sum_of_dice):
    unique_sums, counts = np.unique(sum_of_dice, return_counts=True)
    probabilities = counts / sum(counts)
    result = {sum_val: prob for sum_val, prob in zip(unique_sums, probabilities)}
    return result

n_values = [500, 1000, 2000, 5000, 10000, 15000, 20000, 50000, 100000]

for n in n_values:
    print(f"Number of throws: {n}")

    dice1 = np.random.randint(1, 7, size=n)
    dice2 = np.random.randint(1, 7, size=n)

    sum_of_dice = dice1 + dice2

    probabilities = calculate_probabilities(sum_of_dice)

    sums = list(probabilities.keys())
    probs = list(probabilities.values())

    plt.bar(sums, probs)
    plt.xticks(range(2, 13))

    plt.show()

    print('=' * 200)
#++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
import numpy as np
import matplotlib.pyplot as plt

def calculate_probabilities(frequencies, n):
    probabilities = frequencies / n
    result = {sum_val: prob for sum_val, prob in zip(range(2, 13), probabilities)}
    return result

num_throws = 1000000

dice1 = np.random.randint(1, 7, size=num_throws)
dice2 = np.random.randint(1, 7, size=num_throws)

sum_of_dice = dice1 + dice2

frequencies, _ = np.histogram(sum_of_dice, bins=np.arange(2, 14))

probabilities = calculate_probabilities(frequencies, num_throws)


sums = list(probabilities.keys())
probs = list(probabilities.values())

plt.bar(sums, probs)
plt.xticks(range(2, 13))
plt.show()
print('=' * 200)



#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
import numpy as np
import matplotlib.pyplot as plt

def calculate_probabilities(frequencies, n):
    probabilities = frequencies / n
    result = {sum_val: prob for sum_val, prob in zip(range(2, 13), probabilities)}
    return result

num_throws = 1000000

dice1 = np.random.randint(1, 7, size=num_throws)
dice2 = np.random.randint(1, 7, size=num_throws)

sum_of_dice = dice1 + dice2

frequencies, h2 = np.histogram(sum_of_dice, bins=np.arange(2, 14))

plt.bar(h2[:-1], frequencies / num_throws)
plt.xticks(range(2, 13))
plt.title(f"Dice Throwing Simulation (n={num_throws})")

plt.show()

print('=' * 200)
#++++++++++++++++++++++EXERCISE-2++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# ...
# Number of throws: 500
# ...
# Number of throws: 1000
# ...
# Number of throws: 2000
# ...
# Number of throws: 5000
# ...
# Number of throws: 10000
# ...
# Number of throws: 15000
# ...
# Number of throws: 20000
# ...
# Number of throws: 50000
# ...
# Number of throws: 100000
# ...
# Number of throws: 500
# ...
# Number of throws: 1000
# ...
# Number of throws: 2000
# ...
# Number of throws: 5000
# ...
# Number of throws: 10000
# ...
# Number of throws: 15000
# ...
# Number of throws: 20000
# ...
# Number of throws: 50000
# ...
# Number of throws: 100000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


data = pd.read_csv('weight-height.csv')

X = data['Height'].values.reshape(-1, 1)  # Reshape to ensure it's a 2D array
y = data['Weight'].values

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='blue', alpha=0.5, label='Original data')
plt.plot(X, y_pred, color='red', label='Regression line')
plt.title('Linear Regression: Height vs Weight')
plt.xlabel('Height (inches)')
plt.ylabel('Weight (pounds)')
plt.legend()
rmse =np.sqrt(mean_squared_error(y,y_pred))
r2 = r2_score(y,y_pred)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2) value:", r2)

plt.show()
# Out:
# Root Mean Squared Error (RMSE): 12.218571272826033
# R-squared (R2) value: 0.8551742120609958
